# %%
import numpy as np

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]
#Matrix
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]
#Matrix
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])

#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])

# %%
#Daalgavar1
#1
hansh = 3460
annual_salary_mnt = Salary * hansh
for i in range(len(Players)):
    print(f"{Players[i]}'s Төгрөгөөр жил бүрийн цалин:")
    for j in range(len(Seasons)):
        print(f"  {Seasons[j]}: ₮{annual_salary_mnt[i][j]:,.0f}")
    print()
# Out:
# KobeBryant's Төгрөгөөр жил бүрийн цалин:
#   2005: ₮55,176,187,500
#   2006: ₮61,306,875,000
#   2007: ₮67,437,562,500
#   2008: ₮73,568,250,000
#   2009: ₮79,698,937,500
#   2010: ₮85,829,625,000
#   2011: ₮87,345,945,780
#   2012: ₮96,358,055,540
#   2013: ₮105,370,165,300
#   2014: ₮81,310,000,000
#
# JoeJohnson's Төгрөгөөр жил бүрийн цалин:
#   2005: ₮41,520,000,000
#   2006: ₮44,094,893,940
#   2007: ₮46,669,784,420
#   2008: ₮49,244,681,820
#   2009: ₮51,819,568,840
#   2010: ₮56,482,770,000
#   2011: ₮62,413,462,580
#   2012: ₮68,344,151,700
#   2013: ₮74,274,844,280
#   2014: ₮80,205,533,400
#
# LeBronJames's Төгрөгөөр жил бүрийн цалин:
#   2005: ₮15,991,428,000
#   2006: ₮20,165,191,400
#   2007: ₮45,122,725,000
#   2008: ₮49,860,610,260
#   2009: ₮54,598,495,520
#   2010: ₮50,170,000,000
#   2011: ₮55,437,850,000
#   2012: ₮60,705,700,000
#   2013: ₮65,973,550,000
#   2014: ₮71,429,624,000
#
# CarmeloAnthony's Төгрөгөөр жил бүрийн цалин:
#   2005: ₮12,849,194,400
# ...

# %%
#2
FieldGoalPercentage = (FieldGoals / FieldGoalAttempts) * 100
for i in range(len(Players)):
    print(f"{Players[i]}'s Field Goal Percentage:")
    for j in range(len(Seasons)):
        print(f"  {Seasons[j]}: {FieldGoalPercentage[i][j]:.2f}%")
    print()
# Out:
# KobeBryant's Field Goal Percentage:
#   2005: 45.01%
#   2006: 46.27%
#   2007: 45.86%
#   2008: 46.73%
#   2009: 45.63%
#   2010: 45.15%
#   2011: 42.96%
#   2012: 46.27%
#   2013: 42.47%
#   2014: 37.31%
#
# JoeJohnson's Field Goal Percentage:
#   2005: 45.30%
#   2006: 47.06%
#   2007: 43.22%
#   2008: 43.66%
#   2009: 45.82%
#   2010: 44.27%
#   2011: 45.44%
#   2012: 42.30%
#   2013: 45.38%
#   2014: 43.51%
#
# LeBronJames's Field Goal Percentage:
#   2005: 48.00%
#   2006: 47.62%
#   2007: 48.36%
#   2008: 48.92%
#   2009: 50.26%
#   2010: 51.04%
#   2011: 53.12%
#   2012: 56.50%
#   2013: 56.69%
#   2014: 48.79%
#
# CarmeloAnthony's Field Goal Percentage:
#   2005: 48.09%
#   2006: 47.56%
#   2007: 49.16%
#   2008: 44.32%
#   2009: 45.81%
#   2010: 45.51%
#   2011: 43.02%
#   2012: 44.93%
#   2013: 45.22%
#   2014: 44.42%
#
# DwightHoward's Field Goal Percentage:
#   2005: 53.12%
#   2006: 60.25%
#   2007: 59.86%
#   2008: 57.20%
#   2009: 61.15%
#   2010: 59.29%
# ...

# %%
#3a
salary_per_minute_field = Salary / MinutesPlayed
for i in range(len(Players)):
    print(f"{Players[i]}'s Salary per Minute (Minutes Spent in the Field):")
    for j in range(len(Seasons)):
        print(f"  {Seasons[j]}: ${salary_per_minute_field[i][j]:.2f}")
    print()
# Out:
# KobeBryant's Salary per Minute (Minutes Spent in the Field):
#   2005: $4866.30
#   2006: $5642.91
#   2007: $6106.09
#   2008: $7183.28
#   2009: $8125.00
#   2010: $8926.32
#   2011: $11310.26
#   2012: $9243.00
#   2013: $172055.40
#   2014: $19469.76
#
# JoeJohnson's Salary per Minute (Minutes Spent in the Field):
#   2005: $3592.81
#   2006: $5402.37
#   2007: $4034.81
#   2008: $4555.88
#   2009: $5189.45
#   2010: $6391.74
#   2011: $8480.76
#   2012: $7476.40
#   2013: $8336.59
#   2014: $8305.55
#
# LeBronJames's Salary per Minute (Minutes Spent in the Field):
#   2005: $1375.13
#   2006: $1826.99
#   2007: $4308.31
#   2008: $4718.59
#   2009: $5320.27
#   2010: $4733.92
#   2011: $6888.44
#   2012: $6098.37
#   2013: $6570.47
#   2014: $8280.95
#
# CarmeloAnthony's Salary per Minute (Minutes Spent in the Field):
#   2005: $1262.71
#   2006: $1888.19
#   2007: $4647.63
#   2008: $6328.76
#   2009: $5990.85
#   2010: $6233.82
#   2011: $9871.31
#   2012: $7836.42
# ...

# %%
#3b
total_minutes_played = np.sum(MinutesPlayed, axis=1)
salary_per_minute_total = Salary / total_minutes_played
for i in range(len(Players)):
    print(f"{Players[i]}'s Salary per Minute (Total Minutes):")
    for j in range(len(Seasons)):
        print(f"  {Seasons[j]}: ${salary_per_minute_total[i][j]:.2f}")
    print()
# Out:
# KobeBryant's Salary per Minute (Total Minutes):
#   2005: $642.71
#   2006: $638.72
#   2007: $666.14
#   2008: $862.12
#   2009: $881.13
#   2010: $1007.12
#   2011: $997.61
#   2012: $1153.65
#   2013: $1950.04
#   2014: $1012.84
#
# JoeJohnson's Salary per Minute (Total Minutes):
#   2005: $483.64
#   2006: $459.40
#   2007: $461.00
#   2008: $577.08
#   2009: $572.90
#   2010: $662.76
#   2011: $712.85
#   2012: $818.25
#   2013: $1374.57
#   2014: $999.09
#
# LeBronJames's Salary per Minute (Total Minutes):
#   2005: $186.27
#   2006: $210.09
#   2007: $445.72
#   2008: $584.30
#   2009: $603.62
#   2010: $588.69
#   2011: $633.18
#   2012: $726.80
#   2013: $1220.95
#   2014: $889.77
#
# CarmeloAnthony's Salary per Minute (Total Minutes):
#   2005: $149.67
#   2006: $169.21
#   2007: $445.72
#   2008: $584.30
#   2009: $603.62
#   2010: $696.25
#   2011: $731.81
#   2012: $805.72
#   2013: $1434.81
#   2014: $967.93
#
# DwightHoward's Salary per Minute (Total Minutes):
# ...

# %%
#4
total_salary = np.sum(Salary, axis=1)
highest_paid_index = np.argmax(total_salary)
highest_paid_player = Players[highest_paid_index]
highest_paid_salary = total_salary[highest_paid_index]
highest_paid_salary_tug = highest_paid_salary*3460
print(f"Хамгийн их орлоготой тамирчин бол {highest_paid_player}, түүний цалингийн нийлбэр ${highest_paid_salary:.2f},төгрөгөөр илэрхийлбэл {highest_paid_salary_tug:.2f}")
# Out:
# Хамгийн их орлоготой тамирчин бол KobeBryant, түүний цалингийн нийлбэр $229306822.00,төгрөгөөр илэрхийлбэл 793401604120.00

# %%
#5
total_points = np.sum(Points, axis=1)
salary_per_point = Salary / total_points[:, np.newaxis]
for i in range(len(Players)):
    print(f"{Players[i]}'s Annual Salary per Point:")
    for j in range(len(Seasons)):
        print(f"  {Seasons[j]}: ${salary_per_point[i][j]:.2f}")
    print()
# Out:
# KobeBryant's Annual Salary per Point:
#   2005: $864.42
#   2006: $960.47
#   2007: $1056.52
#   2008: $1152.56
#   2009: $1248.61
#   2010: $1344.66
#   2011: $1368.41
#   2012: $1509.60
#   2013: $1650.79
#   2014: $1273.85
#
# JoeJohnson's Annual Salary per Point:
#   2005: $846.56
#   2006: $899.06
#   2007: $951.56
#   2008: $1004.06
#   2009: $1056.56
#   2010: $1151.64
#   2011: $1272.56
#   2012: $1393.48
#   2013: $1514.41
#   2014: $1635.33
#
# LeBronJames's Annual Salary per Point:
#   2005: $219.21
#   2006: $276.42
#   2007: $618.54
#   2008: $683.48
#   2009: $748.43
#   2010: $687.73
#   2011: $759.94
#   2012: $832.15
#   2013: $904.36
#   2014: $979.15
#
# CarmeloAnthony's Annual Salary per Point:
#   2005: $210.51
#   2006: $266.09
#   2007: $739.26
#   2008: $816.88
#   2009: $894.50
#   2010: $972.12
#   2011: $1049.75
#   2012: $1102.55
#   2013: $1270.19
#   2014: $1273.06
#
# DwightHoward's Annual Salary per Point:
#   2005: $328.14
#   2006: $351.03
# ...

# %%
#Daalgavar2
#1
#Тоглогч бүрийн нэг тоглолтын дундаж оноог ол.
average_points_per_game = np.mean(Points / Games, axis=1)
for i in range(len(Players)):
    print(f"{Players[i]}'s Average Points per Game: {average_points_per_game[i]:.2f}")
# Out:
# KobeBryant's Average Points per Game: 26.58
# JoeJohnson's Average Points per Game: 19.30
# LeBronJames's Average Points per Game: 27.99
# CarmeloAnthony's Average Points per Game: 26.06
# DwightHoward's Average Points per Game: 18.75
# ChrisBosh's Average Points per Game: 20.47
# ChrisPaul's Average Points per Game: 18.67
# KevinDurant's Average Points per Game: 26.86
# DerrickRose's Average Points per Game: nan
# DwayneWade's Average Points per Game: 24.53
# /tmp/ipykernel_93670/3138077610.py:5: RuntimeWarning: invalid value encountered in divide
#   average_points_per_game = np.mean(Points / Games, axis=1)

# %%
#2
#Тоглогч бүрийн цалингийн далайцыг ол.
salary_range = np.ptp(Salary, axis=1)
for i in range(len(Players)):
    print(f"{Players[i]}'s Salary Range: ${salary_range[i]:,.2f}")
# Out:
# KobeBryant's Salary Range: $14,506,930.00
# JoeJohnson's Salary Range: $11,180,790.00
# LeBronJames's Salary Range: $16,022,600.00
# CarmeloAnthony's Salary Range: $18,744,360.00
# DwightHoward's Salary Range: $16,943,111.00
# ChrisBosh's Salary Range: $17,296,400.00
# ChrisPaul's Salary Range: $16,924,323.00
# KevinDurant's Salary Range: $18,995,624.00
# DerrickRose's Salary Range: $18,862,875.00
# DwayneWade's Salary Range: $15,641,080.00

# %%
#3
# Тоглогч бүрийн цалингийн дундаж хэмжээг ол.
average_salary = np.mean(Salary, axis=1)
for i in range(len(Players)):
    print(f"{Players[i]}'s Average Salary: ${average_salary[i]:,.2f}")
# Out:
# KobeBryant's Average Salary: $22,930,682.20
# JoeJohnson's Average Salary: $16,620,511.30
# LeBronJames's Average Salary: $14,146,103.30
# CarmeloAnthony's Average Salary: $15,162,271.50
# DwightHoward's Average Salary: $14,054,650.30
# ChrisBosh's Average Salary: $13,800,811.30
# ChrisPaul's Average Salary: $11,605,145.90
# KevinDurant's Average Salary: $8,851,029.60
# DerrickRose's Average Salary: $7,544,521.10
# DwayneWade's Average Salary: $13,085,110.60
